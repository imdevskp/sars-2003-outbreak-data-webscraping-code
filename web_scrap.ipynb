# %% [markdown]
# # Source

# %% [markdown]
# https://www.who.int/csr/sars/country/en/

# %% [markdown]
# # Libraries

# %%
# to get web contents
import requests 
# scrap and clean web contents
from bs4 import BeautifulSoup

# numerical opeations
import numpy as np
# storing and processing in a dataframe
import pandas as pd

# %% [markdown]
# # Extracting links and date each days report

# %%
# get data from main page
# ======================

# url of the main page
who_url = "https://www.who.int/csr/sars/country/en/"
# get contents of the page
who_req = requests.get(who_url)
# convert the contents into soup object using html parser
who_soup = BeautifulSoup(who_req.content, "html.parser")
# find all 'div' elements with class 'col_2-1_1'
who_data = who_soup.findAll('div', attrs={'class':'col_2-1_1'})
# no. of who_data
print(len(who_data))
# Out:
# 1

# %%
# find all the links in who_data
# ==============================

# find all the links in who_data
links = who_data[0].findAll('a')
# no. of links
print(len(links))
# Out:
# 99

# %%
# get each days link and date
# ==========================

# container for situation reports links
situation_reports_links = []
# container for situation reports dates
situation_reports_dates = []

# enumerate through links and get and store address and date
for ind, a in enumerate(links):
    # no tables at that index
    if(ind==96): 
        pass
    else:
        # get address
        address = 'https://www.who.int'+a.get('href')
        # append to situation_reports_links
        situation_reports_links.append(address)
        # get date
        date = a.contents[0]
        # append to situation_reports_dates
        situation_reports_dates.append(date)
            
# first few contents
# print(situation_reports_links[:3])
# print(situation_reports_dates[:3])

# no. of itemes in the lists
print(len(situation_reports_links))
print(len(situation_reports_dates))
# Out:
# 98
# 98

# %% [markdown]
# # Scrap tables

# %%
# scarping html tables to dataframes 

# container for situation report
sr_df = []

# go through each days report link
for ind, sr_link in enumerate(situation_reports_links):

    # print index
    print('Index :', '\t', ind)
    # print situation report link
    print('Link :', '\t', sr_link)
    # print situation report date
    print('Date :', '\t', situation_reports_dates[ind])
    
    # getting html contents
    sr_req = requests.get(sr_link)
    # create a soup object
    sr_soup = BeautifulSoup(sr_req.content, "html.parser")
    
    # find the first table
    sr_table = sr_soup.find_all('table')[0]
    # find all the rows in the table
    sr_rows = sr_table.find_all('tr')
    
    
    # storing table as list of rows
    # =============================
    
    # container for table rows
    row_list = []

    # loop through rows 
    for tr in sr_rows:
        td = tr.find_all('td')
        row = [i.text for i in td]
        row_list.append(row)
        
    
    # saving as a dataframes
    # ======================
    
    # different dates data has different table format

    if(ind<=20):
        df_bs = pd.DataFrame(row_list[1:len(row_list)-1], columns=row_list[0])

    elif(ind<=26):
        cols = ['Country', 'Cumulative number of case(s)', 
                'Number of new cases since last WHO update', 
                'Number of deaths', 'Number recovered', 
                'Local chain(s) of transmission']
        df_bs = pd.DataFrame(row_list[2:len(row_list)-1], columns=cols)

    elif(ind<=95):
        cols = ['Country', 'Cumulative number of case(s)', 
                'Number of new cases since last WHO update', 
                'Number of deaths', 'Number recovered', 
                'Local chain(s) of transmission', 
                'Date of last report']
        df_bs = pd.DataFrame(row_list[2:len(row_list)-1], columns=cols)

    else:
        df_bs = pd.DataFrame(row_list[2:len(row_list)-1], columns=row_list[1])
        
    # append to situation report container
    sr_df.append(df_bs)
    
    # no. of columns
    print('No. of columns in the dataframe :', '\t', len(df_bs.columns))
    # list of columns
    print('Columns :', '\t', df_bs.columns)
    
    # create a horizontal row
    print('\n' + '='*80 + '\n')
    
    # save as a csv file
    # df_bs.to_csv(date+'.csv')

print(len(sr_df))
# Out:
# Index : 	 0
# Link : 	 https://www.who.int/csr/sars/country/table/en/
# Date : 	 17 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index([' Country', ' Total number of case(s)', ' Number of deaths ',
#        ' Local transmission'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 1
# Link : 	 https://www.who.int/csr/sars/country/tablemarch18/en/
# Date : 	 18 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country', 'Cumulative number of case(s) §', 'Number of deaths',
#        'Local transmission'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 2
# Link : 	 https://www.who.int/csr/sars/country/2003_19_03/en/
# Date : 	 19 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country', 'Cumulative number of case(s) §', 'Number of deaths',
#        'Local transmission'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 3
# Link : 	 https://www.who.int/csr/sars/country/2003_03_20/en/
# Date : 	 20 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) § ', 'Number of deaths ',
#        'Local transmission '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 4
# Link : 	 https://www.who.int/csr/sars/country/2003_03_21/en/
# Date : 	 21 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) § ', 'Number of deaths ',
#        'Local transmission '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 5
# Link : 	 https://www.who.int/csr/sars/country/2003_03_22/en/
# Date : 	 22 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) § ', 'Number of deaths ',
#        'Local transmission '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 6
# Link : 	 https://www.who.int/csr/sars/country/2003_03_24/en/
# Date : 	 24 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s)  ', 'Number of deaths ',
#        'Local transmission* '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 7
# Link : 	 https://www.who.int/csr/sars/country/2003_03_25/en/
# Date : 	 25 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s)  ', 'Number of deaths ',
#        'Local transmission* '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 8
# Link : 	 https://www.who.int/csr/sars/country/2003_03_26/en/
# Date : 	 26 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) ', 'Number of deaths ',
#        'Local transmission* '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 9
# Link : 	 https://www.who.int/csr/sars/country/2003_03_27/en/
# Date : 	 27 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) ', 'Number of deaths ',
#        'Local transmission* '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 10
# Link : 	 https://www.who.int/csr/sars/country/2003_03_28/en/
# Date : 	 28 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) ', 'Number of deaths ',
#        ' Local chain(s) of transmission2  '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 11
# Link : 	 https://www.who.int/csr/sars/country/2003_03_29/en/
# Date : 	 29 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) ', 'Number of deaths ',
#        ' Local chain(s) of transmission2  '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 12
# Link : 	 https://www.who.int/csr/sars/country/2003_03_31/en/
# Date : 	 31 March 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) ', 'Number of deaths ',
#        ' Local chain(s) of transmission2  '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 13
# Link : 	 https://www.who.int/csr/sars/country/2003_04_01/en/
# Date : 	 1 April 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) ', 'Number of deaths ',
#        ' Local chain(s) of transmission2  '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 14
# Link : 	 https://www.who.int/csr/sars/country/2003_04_02/en/
# Date : 	 2 April 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) ', 'Number of deaths ',
#        'Local chain(s) of transmission2 '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 15
# Link : 	 https://www.who.int/csr/sars/country/2003_04_03/en/
# Date : 	 3 April 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) ', 'Number of deaths ',
#        'Local chain(s) of transmission2 '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 16
# Link : 	 https://www.who.int/csr/sars/country/2003_04_04/en/
# Date : 	 4 April 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s) ', 'Number of deaths ',
#        'Local chain(s) of transmission2 '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 17
# Link : 	 https://www.who.int/csr/sars/country/2003_04_05/en/
# Date : 	 5 April 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s)  ', 'Number of deaths ',
#        'Local chain(s) of  transmission 2  '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 18
# Link : 	 https://www.who.int/csr/sars/country/2003_04_07/en/
# Date : 	 7 April 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s)  ', 'Number of deaths ',
#        'Local chain(s) of transmission 2  '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 19
# Link : 	 https://www.who.int/csr/sars/country/2003_04_08/en/
# Date : 	 8 April 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s)  ', 'Number of deaths ',
#        'Local chain(s) of transmission 2  '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 20
# Link : 	 https://www.who.int/csr/sars/country/2003_04_09/en/
# Date : 	 9 April 2003
# No. of columns in the dataframe : 	 4
# Columns : 	 Index(['Country ', 'Cumulative number of case(s)  ', 'Number of deaths ',
#        'Local chain(s) of transmission 2  '],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 21
# Link : 	 https://www.who.int/csr/sars/country/2003_04_10/en/
# Date : 	 10 April 2003
# No. of columns in the dataframe : 	 6
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 22
# Link : 	 https://www.who.int/csr/sars/country/2003_04_11/en/
# Date : 	 11 April 2003
# No. of columns in the dataframe : 	 6
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 23
# Link : 	 https://www.who.int/csr/sars/country/2003_04_12/en/
# Date : 	 12 April 2003
# No. of columns in the dataframe : 	 6
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 24
# Link : 	 https://www.who.int/csr/sars/country/2003_04_14/en/
# Date : 	 14 April 2003
# No. of columns in the dataframe : 	 6
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 25
# Link : 	 https://www.who.int/csr/sars/country/2003_04_15/en/
# Date : 	 15 April 2003
# No. of columns in the dataframe : 	 6
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 26
# Link : 	 https://www.who.int/csr/sars/country/2003_04_16/en/
# Date : 	 16 April 2003
# No. of columns in the dataframe : 	 6
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 27
# Link : 	 https://www.who.int/csr/sars/country/2003_04_17/en/
# Date : 	 17 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 28
# Link : 	 https://www.who.int/csr/sars/country/2003_04_18/en/
# Date : 	 18 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 29
# Link : 	 https://www.who.int/csr/sars/country/2003_04_19/en/
# Date : 	 19 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 30
# Link : 	 https://www.who.int/csr/sars/country/2003_04_21/en/
# Date : 	 21 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 31
# Link : 	 https://www.who.int/csr/sars/country/2003_04_22/en/
# Date : 	 22 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 32
# Link : 	 https://www.who.int/csr/sars/country/2003_04_23/en/
# Date : 	 23 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 33
# Link : 	 https://www.who.int/csr/sars/country/2003_04_24/en/
# Date : 	 24 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 34
# Link : 	 https://www.who.int/csr/sars/country/2003_04_25/en/
# Date : 	 25 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 35
# Link : 	 https://www.who.int/csr/sars/country/2003_04_26/en/
# Date : 	 26 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 36
# Link : 	 https://www.who.int/csr/sars/country/2003_04_28/en/
# Date : 	 28 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 37
# Link : 	 https://www.who.int/csr/sars/country/2003_04_29/en/
# Date : 	 29 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 38
# Link : 	 https://www.who.int/csr/sars/country/2003_04_30/en/
# Date : 	 30 April 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 39
# Link : 	 https://www.who.int/csr/sars/country/2003_05_01/en/
# Date : 	 1 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 40
# Link : 	 https://www.who.int/csr/sars/country/2003_05_02/en/
# Date : 	 2 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 41
# Link : 	 https://www.who.int/csr/sars/country/2003_05_03/en/
# Date : 	 3 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 42
# Link : 	 https://www.who.int/csr/sars/country/2003_05_05/en/
# Date : 	 5 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 43
# Link : 	 https://www.who.int/csr/sars/country/2003_05_06/en/
# Date : 	 6 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 44
# Link : 	 https://www.who.int/csr/sars/country/2003_05_07/en/
# Date : 	 7 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 45
# Link : 	 https://www.who.int/csr/sars/country/2003_05_08/en/
# Date : 	 8 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 46
# Link : 	 https://www.who.int/csr/sars/country/2003_05_09/en/
# Date : 	 9 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 47
# Link : 	 https://www.who.int/csr/sars/country/2003_05_10/en/
# Date : 	 10 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 48
# Link : 	 https://www.who.int/csr/sars/country/2003_05_12/en/
# Date : 	 12 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 49
# Link : 	 https://www.who.int/csr/sars/country/2003_05_13/en/
# Date : 	 13 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 50
# Link : 	 https://www.who.int/csr/sars/country/2003_05_14/en/
# Date : 	 14 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 51
# Link : 	 https://www.who.int/csr/sars/country/2003_05_15/en/
# Date : 	 15 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 52
# Link : 	 https://www.who.int/csr/sars/country/2003_05_16/en/
# Date : 	 16 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 53
# Link : 	 https://www.who.int/csr/sars/country/2003_05_17/en/
# Date : 	 17 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 54
# Link : 	 https://www.who.int/csr/sars/country/2003_05_19/en/
# Date : 	 19 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 55
# Link : 	 https://www.who.int/csr/sars/country/2003_05_20/en/
# Date : 	 20 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 56
# Link : 	 https://www.who.int/csr/sars/country/2003_05_21/en/
# Date : 	 21 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 57
# Link : 	 https://www.who.int/csr/sars/country/2003_05_22/en/
# Date : 	 22 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 58
# Link : 	 https://www.who.int/csr/sars/country/2003_05_23/en/
# Date : 	 23 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 59
# Link : 	 https://www.who.int/csr/sars/country/2003_05_24a/en/
# Date : 	 24 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 60
# Link : 	 https://www.who.int/csr/sars/country/2003_05_26/en/
# Date : 	 26 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 61
# Link : 	 https://www.who.int/csr/sars/country/2003_05_27/en/
# Date : 	 27 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 62
# Link : 	 https://www.who.int/csr/sars/country/2003_05_28/en/
# Date : 	 28 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 63
# Link : 	 https://www.who.int/csr/sars/country/2003_05_29/en/
# Date : 	 29 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 64
# Link : 	 https://www.who.int/csr/sars/country/2003_05_30/en/
# Date : 	 30 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 65
# Link : 	 https://www.who.int/csr/sars/country/2003_05_31/en/
# Date : 	 31 May 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 66
# Link : 	 https://www.who.int/csr/sars/country/2003_06_02/en/
# Date : 	 2 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 67
# Link : 	 https://www.who.int/csr/sars/country/2003_06_03/en/
# Date : 	 3 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 68
# Link : 	 https://www.who.int/csr/sars/country/2003_06_04/en/
# Date : 	 4 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 69
# Link : 	 https://www.who.int/csr/sars/country/2003_06_05/en/
# Date : 	 5 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 70
# Link : 	 https://www.who.int/csr/sars/country/2003_06_06/en/
# Date : 	 6 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 71
# Link : 	 https://www.who.int/csr/sars/country/2003_06_09/en/
# Date : 	 9 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 72
# Link : 	 https://www.who.int/csr/sars/country/2003_06_10/en/
# Date : 	 10 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 73
# Link : 	 https://www.who.int/csr/sars/country/2003_06_11/en/
# Date : 	 11 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 74
# Link : 	 https://www.who.int/csr/sars/country/2003_06_12/en/
# Date : 	 12 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 75
# Link : 	 https://www.who.int/csr/sars/country/2003_06_13/en/
# Date : 	 13 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 76
# Link : 	 https://www.who.int/csr/sars/country/2003_06_16/en/
# Date : 	 16 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 77
# Link : 	 https://www.who.int/csr/sars/country/2003_06_17/en/
# Date : 	 17 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 78
# Link : 	 https://www.who.int/csr/sars/country/2003_06_18/en/
# Date : 	 18 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 79
# Link : 	 https://www.who.int/csr/sars/country/2003_06_19/en/
# Date : 	 19 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 80
# Link : 	 https://www.who.int/csr/sars/country/2003_06_20/en/
# Date : 	 20 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 81
# Link : 	 https://www.who.int/csr/sars/country/2003_06_23/en/
# Date : 	 23 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 82
# Link : 	 https://www.who.int/csr/sars/country/2003_06_24/en/
# Date : 	 24 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 83
# Link : 	 https://www.who.int/csr/sars/country/2003_06_25/en/
# Date : 	 25 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 84
# Link : 	 https://www.who.int/csr/sars/country/2003_06_26/en/
# Date : 	 26 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 85
# Link : 	 https://www.who.int/csr/sars/country/2003_06_27/en/
# Date : 	 27 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 86
# Link : 	 https://www.who.int/csr/sars/country/2003_06_30/en/
# Date : 	 30 June 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 87
# Link : 	 https://www.who.int/csr/sars/country/2003_07_01/en/
# Date : 	 1 July 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 88
# Link : 	 https://www.who.int/csr/sars/country/2003_07_02/en/
# Date : 	 2 July 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 89
# Link : 	 https://www.who.int/csr/sars/country/2003_07_03/en/
# Date : 	 3 July 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 90
# Link : 	 https://www.who.int/csr/sars/country/2003_07_04/en/
# Date : 	 4 July 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 91
# Link : 	 https://www.who.int/csr/sars/country/2003_07_07/en/
# Date : 	 7 July 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 92
# Link : 	 https://www.who.int/csr/sars/country/2003_07_08/en/
# Date : 	 8 July 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 93
# Link : 	 https://www.who.int/csr/sars/country/2003_07_09/en/
# Date : 	 9 July 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 94
# Link : 	 https://www.who.int/csr/sars/country/2003_07_10/en/
# Date : 	 10 July 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 95
# Link : 	 https://www.who.int/csr/sars/country/2003_07_11/en/
# Date : 	 11 July 2003
# No. of columns in the dataframe : 	 7
# Columns : 	 Index(['Country', 'Cumulative number of case(s)',
#        'Number of new cases since last WHO update', 'Number of deaths',
#        'Number recovered', 'Local chain(s) of transmission',
#        'Date of last report'],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 96
# Link : 	 https://www.who.int/csr/sars/country/table2003_09_23/en/
# Date : 	 26 September 2003
# No. of columns in the dataframe : 	 15
# Columns : 	 Index(['Areas', 'Female', 'Male', 'Total', 'Median age (range)',
#        'Number of deaths^a ', 'Case fatality ratio  (%) ',
#        'Number of imported cases (%)', 'Number of HCW affected (%)',
#        'Date onset first probable case', 'Date onset last probable case', '',
#        '', '', ''],
#       dtype='object')
#
# ================================================================================
#
# Index : 	 97
# Link : 	 https://www.who.int/csr/sars/country/table2004_04_21/en/
# Date : 	 21 April 2004
# No. of columns in the dataframe : 	 11
# Columns : 	 Index(['Areas', 'Female', 'Male', 'Total', 'Median age (range)',
#        'Number of deaths^a  ', 'Case fatality ratio  (%) ',
#        'Number of imported cases (%)', 'Number of HCW affected (%)',
#        'Date onset first probable case', 'Date onset last probable case'],
#       dtype='object')
#
# ================================================================================
#
# 98

# %%
# first few rows first table
sr_df[0].head()
# Out:
#                                              Country  Total number of case(s)  \
# 0                                           Germany                        1
# 1                                           Canada                          8
# 2                                         Singapore                        20
# 3   Hong Kong Special Administrative Region of Ch...                      95
# 4                                        Switzerland                        2
#
#    Number of deaths   Local transmission
# 0                  0               None*
# 1                  2                 Yes
# 2                  0                 Yes
# 3                1**                 Yes
# 4                  0   To be determined

# %% [markdown]
# ### Data from March 17th - April 9th

# %%
temp = sr_df.copy()

mar_17_to_apr_9_dfs = temp[:21]
mar_17_to_apr_9_dates = situation_reports_dates[:21]

cols = ['Country', 'Cumulative number of case(s)', 'Number of deaths', 'Local chain(s) of transmission']

for df, date in zip(mar_17_to_apr_9_dfs, mar_17_to_apr_9_dates):
    df.columns = cols
    df['Date'] = date
    df['Number recovered'] = np.nan
    
mar_17_to_apr_9 = pd.concat(mar_17_to_apr_9_dfs)
mar_17_to_apr_9.head()

# print(mar_17_to_apr_9.shape)
# print(sum([len(i) for i in mar_17_to_apr_9_dfs]))
# print(len(mar_17_to_apr_9_dfs))
# Out:
#                                              Country  \
# 0                                           Germany
# 1                                           Canada
# 2                                         Singapore
# 3   Hong Kong Special Administrative Region of Ch...
# 4                                        Switzerland
#
#   Cumulative number of case(s) Number of deaths  \
# 0                           1                 0
# 1                            8                2
# 2                           20                0
# 3                          95               1**
# 4                            2                0
#
#   Local chain(s) of transmission           Date  Number recovered
# 0                          None*  17 March 2003               NaN
# 1                            Yes  17 March 2003               NaN
# 2                            Yes  17 March 2003               NaN
# 3                            Yes  17 March 2003               NaN
# 4              To be determined   17 March 2003               NaN

# %% [markdown]
# ### Data from April 10th - April 16th

# %%
temp = sr_df.copy()

apr_10_to_apr_16_dfs = temp[21:27]
apr_10_to_apr_16_dates = situation_reports_dates[21:27]
        
cols = ['Country', 'Cumulative number of case(s)', 
        'Number of new cases since last WHO update',
        'Number of deaths', 'Number recovered',
        'Local chain(s) of transmission']

for df, date in zip(apr_10_to_apr_16_dfs, apr_10_to_apr_16_dates):
    df.columns = cols
    df['Date'] = date
    
apr_10_to_apr_16 = pd.concat(apr_10_to_apr_16_dfs)
apr_10_to_apr_16.head()

# print(apr_10_to_apr_16.shape)
# print(sum([len(i) for i in apr_10_to_apr_16_dfs]))
# print(len(apr_10_to_apr_16_dfs))
# Out:
#                                              Country  \
# 0                                            Brazil
# 1                                            Canada
# 2                                             China
# 3  China, Hong Kong Special Administrative Region...
# 4                                      China, Taiwan
#
#   Cumulative number of case(s) Number of new cases since last WHO update  \
# 0                     \n     2                                         1
# 1                    \n     97                                         3
# 2                  \n     1290                                        10
# 3                          998                                        28
# 4                           19                                         0
#
#   Number of deaths Number recovered Local chain(s) of transmission  \
# 0                0                0                         \nNone
# 1               10               22                            Yes
# 2               55             1025                            Yes
# 3               30              154                            Yes
# 4                0                5                            Yes
#
#             Date
# 0  10 April 2003
# 1  10 April 2003
# 2  10 April 2003
# 3  10 April 2003
# 4  10 April 2003

# %% [markdown]
# ### Data from April 17th - July 11th

# %%
temp = sr_df.copy()

apr_17_to_july_11_dfs = temp[27:96]
apr_17_to_july_11_dates = situation_reports_dates[27:96]
        
cols = ['Country', 'Cumulative number of case(s)', 
        'Number of new cases since last WHO update',
        'Number of deaths', 'Number recovered',
        'Local chain(s) of transmission', 'Date of last report']

for df, date in zip(apr_17_to_july_11_dfs, apr_17_to_july_11_dates):
    df.columns = cols
    df['Date'] = date
    
apr_17_to_july_11 = pd.concat(apr_17_to_july_11_dfs)
apr_17_to_july_11.head()

# print(apr_17_to_july_11.shape)
# print(sum([len(i) for i in apr_17_to_july_11_dfs]))
# print(len(apr_17_to_july_11_dfs))
# Out:
#                                             Country  \
# 0                                        Australia
# 1                                           Brazil
# 2                                           Canada
# 3                                            China
# 4  China, Hong Kong Special Administrative Region 5
#
#   Cumulative number of case(s) Number of new cases since last WHO update  \
# 0                            3                                         3
# 1                            2                                         0
# 2                          126                                        23
# 3                         1457                                        25
# 4                         1297                                        29
#
#   Number of deaths Number recovered Local chain(s) of transmission  \
# 0                0                3                           None
# 1                0                0                           None
# 2               12               46                            Yes
# 3               65             1107                            Yes
# 4               65              272                            Yes
#
#   Date of last report           Date
# 0         17 Apr 2003  17 April 2003
# 1         16 Apr 2003  17 April 2003
# 2         17 Apr 2003  17 April 2003
# 3         17 Apr 2003  17 April 2003
# 4         17 Apr 2003  17 April 2003

# %% [markdown]
# # Save data

# %%
# subset columns only required columns
df1 = mar_17_to_apr_9[['Date', 'Country', 'Cumulative number of case(s)', 
                       'Number of deaths', 'Number recovered']]
# subset columns only required columns
df2 = apr_10_to_apr_16[['Date', 'Country', 'Cumulative number of case(s)', 
                        'Number of deaths', 'Number recovered']]
# subset columns only required columns
df3 = apr_17_to_july_11[['Date', 'Country', 'Cumulative number of case(s)', 
                         'Number of deaths', 'Number recovered']]

# concateate dataframes
final_df = pd.concat([df1, df2, df3])

# save dataframe as csv
final_df.to_csv('sars_2003_complete_dataset.csv', index=False)
