# %% [markdown]
# # Source

# %% [markdown]
# > Summary of probable SARS cases with onset of illness from 1 November 2002 to 31 July 2003
# > https://www.who.int/csr/sars/country/table2004_04_21/en/

# %% [markdown]
# # Libraries

# %%
# to get web contents
import requests 
# scrap and clean web contents
from bs4 import BeautifulSoup

# numerical opeations
import numpy as np
# storing and processing in a dataframe
import pandas as pd

# to hide warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data

# %%
# link of the data
url = 'https://www.who.int/csr/sars/country/table2004_04_21/en/'

# headers
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

# get web contents
r = requests.get(url, headers=header)

# save data in a dataframe
df = pd.read_html(r.text)[0]

# first few rows
df
# Out:
#                                         Unnamed: 0 Cumulative number of cases  \
# 0                                            Areas                     Female
# 1                                        Australia                          4
# 2                                           Canada                        151
# 3                                            China                       2674
# 4   China, Hong Kong Special Administrative Region                        977
# 5       China, Macao Special Administrative Region                          0
# 6                                    China, Taiwan                        218
# 7                                           France                          1
# 8                                          Germany                          4
# 9                                            India                          0
# 10                                       Indonesia                          0
# 11                                           Italy                          1
# 12                                          Kuwait                          1
# 13                                        Malaysia                          1
# 14                                        Mongolia                          8
# 15                                     New Zealand                          1
# 16                                     Philippines                          8
# 17                             Republic of Ireland                          0
# 18                               Republic of Korea                          0
# 19                                         Romania                          0
# 20                              Russian Federation                          0
# 21                                       Singapore                        161
# 22                                    South Africa                          0
# 23                                           Spain                          0
# 24                                          Sweden                          3
# 25                                     Switzerland                          0
# 26                                        Thailand                          5
# 27                                  United Kingdom                          2
# 28                                   United States                         13
# 29                                        Viet Nam                         39
# 30                                             NaN                        NaN
# 31                                           Total                        NaN
#
#    Cumulative number of cases.1 Cumulative number of cases.2  \
# 0                          Male                        Total
# 1                             2                            6
# 2                           100                          251
# 3                          2607                       5327^b
# 4                           778                         1755
# 5                             1                            1
# 6                           128                        346^c
# 7                             6                            7
# 8                             5                            9
# 9                             3                            3
# 10                            2                            2
# 11                            3                            4
# 12                            0                            1
# 13                            4                            5
# 14                            1                            9
# 15                            0                            1
# 16                            6                           14
# 17                            1                            1
# 18                            3                            3
# 19                            1                            1
# 20                            1                            1
# 21                           77                          238
# 22                            1                            1
# 23                            1                            1
# 24                            2                            5
# 25                            1                            1
# 26                            4                            9
# 27                            2                            4
# 28                           14                           27
# 29                           24                           63
# 30                          NaN                          NaN
# 31                          NaN                         8096
#
#             Unnamed: 4          Unnamed: 5               Unnamed: 6  \
# 0   Median age (range)  Number of deaths^a  Case fatality ratio (%)
# 1            15 (1-45)                   0                        0
# 2            49 (1-98)                  43                       17
# 3        Not available                 349                        7
# 4           40 (0-100)                 299                       17
# 5                   28                   0                        0
# 6            42 (0-93)                  37                       11
# 7         49 (26 - 61)                   1                       14
# 8            44 (4-73)                   0                        0
# 9           25 (25-30)                   0                        0
# 10          56 (47-65)                   0                        0
# 11        30.5 (25-54)                   0                        0
# 12                  50                   0                        0
# 13          30 (26-84)                   2                       40
# 14          32 (17-63)                   0                        0
# 15                  67                   0                        0
# 16          41 (29-73)                   2                       14
# 17                  56                   0                        0
# 18          40 (20-80)                   0                        0
# 19                  52                   0                        0
# 20                  25                   0                        0
# 21           35 (1-90)                  33                       14
# 22                  62                   1                      100
# 23                  33                   0                        0
# 24          43 (33-55)                   0                        0
# 25                  35                   0                        0
# 26           42 (2-79)                   2                       22
# 27          59 (28-74)                   0                        0
# 28           36 (0-83)                   0                        0
# 29          43 (20-76)                   5                        8
# 30                 NaN                 NaN                      NaN
# 31                 NaN                 774                      9.6
#
#                       Unnamed: 7                  Unnamed: 8  \
# 0   Number of imported cases (%)  Number of HCW affected (%)
# 1                        6 (100)                       0 (0)
# 2                          5 (2)                    109 (43)
# 3                 Not Applicable                   1002 (19)
# 4                 Not Applicable                    386 (22)
# 5                        1 (100)                       0 (0)
# 6                         21 (6)                     68 (20)
# 7                        7 (100)                    2 (29)^d
# 8                        9 (100)                      1 (11)
# 9                        3 (100)                       0 (0)
# 10                       2 (100)                       0 (0)
# 11                       4 (100)                       0 (0)
# 12                       1 (100)                       0 (0)
# 13                       5 (100)                       0 (0)
# 14                        8 (89)                       0 (0)
# 15                       1 (100)                       0 (0)
# 16                        7 (50)                      4 (29)
# 17                       1 (100)                       0 (0)
# 18                       3 (100)                       0 (0)
# 19                       1 (100)                       0 (0)
# 20                 Not Available                       0 (0)
# 21                         8 (3)                     97 (41)
# 22                       1 (100)                       0 (0)
# 23                       1 (100)                       0 (0)
# 24                       5 (100)                       0 (0)
# 25                       1 (100)                       0 (0)
# 26                       9 (100)                    1 (11)^d
# 27                       4 (100)                       0 (0)
# 28                      27 (100)                       0 (0)
# 29                         1 (2)                     36 (57)
# 30                           NaN                         NaN
# 31                           142                        1706
#
#                         Unnamed: 9                    Unnamed: 10
# 0   Date onset first probable case  Date onset last probable case
# 1                        26-Feb-03                       1-Apr-03
# 2                        23-Feb-03                      12-Jun-03
# 3                        16-Nov-02                       3-Jun-03
# 4                        15-Feb-03                      31-May-03
# 5                         5-May-03                       5-May-03
# 6                        25-Feb-03                      15-Jun-03
# 7                        21-Mar-03                       3-May-03
# 8                         9-Mar-03                       6-May-03
# 9                        25-Apr-03                       6-May-03
# 10                        6-Apr-03                      17-Apr-03
# 11                       12-Mar-03                      20-Apr-03
# 12                        9-Apr-03                       9-Apr-03
# 13                       14-Mar-03                      22-Apr-03
# 14                       31-Mar-03                       6-May-03
# 15                       20-Apr-03                      20-Apr-03
# 16                       25-Feb-03                       5-May-03
# 17                       27-Feb-03                      27-Feb-03
# 18                       25-Apr-03                      10-May-03
# 19                       19-Mar-03                      19-Mar-03
# 20                        5-May-03                       5-May-03
# 21                       25-Feb-03                       5-May-03
# 22                        3-Apr-03                       3-Apr-03
# 23                       26-Mar-03                      26-Mar-03
# 24                       28-Mar-03                      23-Apr-03
# 25                        9-Mar-03                       9-Mar-03
# 26                       11-Mar-03                      27-May-03
# 27                        1-Mar-03                       1-Apr-03
# 28                       24-Feb-03                    13-Jul-03^e
# 29                       23-Feb-03                      14-Apr-03
# 30                             NaN                            NaN
# 31                             NaN                            NaN

# %% [markdown]
# # Preprocessing

# %%
# subselect rows
df = df.loc[1:29]

# rename columns
df.columns = ['Country/Region', 'Cumulative male cases', 'Cumulative female cases', 
              'Cumulative total cases', 'Median age (range)', 'No. of deaths', 
              'Case fatalities ratio (%)', 'Number of imported cases (%)', 
              'Number of HCW affected (%)', 'Date onset first probable case', 
              'Date onset last probable case']

df
# Out:
#                                     Country/Region Cumulative male cases  \
# 1                                        Australia                     4
# 2                                           Canada                   151
# 3                                            China                  2674
# 4   China, Hong Kong Special Administrative Region                   977
# 5       China, Macao Special Administrative Region                     0
# 6                                    China, Taiwan                   218
# 7                                           France                     1
# 8                                          Germany                     4
# 9                                            India                     0
# 10                                       Indonesia                     0
# 11                                           Italy                     1
# 12                                          Kuwait                     1
# 13                                        Malaysia                     1
# 14                                        Mongolia                     8
# 15                                     New Zealand                     1
# 16                                     Philippines                     8
# 17                             Republic of Ireland                     0
# 18                               Republic of Korea                     0
# 19                                         Romania                     0
# 20                              Russian Federation                     0
# 21                                       Singapore                   161
# 22                                    South Africa                     0
# 23                                           Spain                     0
# 24                                          Sweden                     3
# 25                                     Switzerland                     0
# 26                                        Thailand                     5
# 27                                  United Kingdom                     2
# 28                                   United States                    13
# 29                                        Viet Nam                    39
#
#    Cumulative female cases Cumulative total cases Median age (range)  \
# 1                        2                      6          15 (1-45)
# 2                      100                    251          49 (1-98)
# 3                     2607                 5327^b      Not available
# 4                      778                   1755         40 (0-100)
# 5                        1                      1                 28
# 6                      128                  346^c          42 (0-93)
# 7                        6                      7       49 (26 - 61)
# 8                        5                      9          44 (4-73)
# 9                        3                      3         25 (25-30)
# 10                       2                      2         56 (47-65)
# 11                       3                      4       30.5 (25-54)
# 12                       0                      1                 50
# 13                       4                      5         30 (26-84)
# 14                       1                      9         32 (17-63)
# 15                       0                      1                 67
# 16                       6                     14         41 (29-73)
# 17                       1                      1                 56
# 18                       3                      3         40 (20-80)
# 19                       1                      1                 52
# 20                       1                      1                 25
# 21                      77                    238          35 (1-90)
# 22                       1                      1                 62
# 23                       1                      1                 33
# 24                       2                      5         43 (33-55)
# 25                       1                      1                 35
# 26                       4                      9          42 (2-79)
# 27                       2                      4         59 (28-74)
# 28                      14                     27          36 (0-83)
# 29                      24                     63         43 (20-76)
#
#    No. of deaths Case fatalities ratio (%) Number of imported cases (%)  \
# 1              0                         0                      6 (100)
# 2             43                        17                        5 (2)
# 3            349                         7               Not Applicable
# 4            299                        17               Not Applicable
# 5              0                         0                      1 (100)
# 6             37                        11                       21 (6)
# 7              1                        14                      7 (100)
# 8              0                         0                      9 (100)
# 9              0                         0                      3 (100)
# 10             0                         0                      2 (100)
# 11             0                         0                      4 (100)
# 12             0                         0                      1 (100)
# 13             2                        40                      5 (100)
# 14             0                         0                       8 (89)
# 15             0                         0                      1 (100)
# 16             2                        14                       7 (50)
# 17             0                         0                      1 (100)
# 18             0                         0                      3 (100)
# 19             0                         0                      1 (100)
# 20             0                         0                Not Available
# 21            33                        14                        8 (3)
# 22             1                       100                      1 (100)
# 23             0                         0                      1 (100)
# 24             0                         0                      5 (100)
# 25             0                         0                      1 (100)
# 26             2                        22                      9 (100)
# 27             0                         0                      4 (100)
# 28             0                         0                     27 (100)
# 29             5                         8                        1 (2)
#
#    Number of HCW affected (%) Date onset first probable case  \
# 1                       0 (0)                      26-Feb-03
# 2                    109 (43)                      23-Feb-03
# 3                   1002 (19)                      16-Nov-02
# 4                    386 (22)                      15-Feb-03
# 5                       0 (0)                       5-May-03
# 6                     68 (20)                      25-Feb-03
# 7                    2 (29)^d                      21-Mar-03
# 8                      1 (11)                       9-Mar-03
# 9                       0 (0)                      25-Apr-03
# 10                      0 (0)                       6-Apr-03
# 11                      0 (0)                      12-Mar-03
# 12                      0 (0)                       9-Apr-03
# 13                      0 (0)                      14-Mar-03
# 14                      0 (0)                      31-Mar-03
# 15                      0 (0)                      20-Apr-03
# 16                     4 (29)                      25-Feb-03
# 17                      0 (0)                      27-Feb-03
# 18                      0 (0)                      25-Apr-03
# 19                      0 (0)                      19-Mar-03
# 20                      0 (0)                       5-May-03
# 21                    97 (41)                      25-Feb-03
# 22                      0 (0)                       3-Apr-03
# 23                      0 (0)                      26-Mar-03
# 24                      0 (0)                      28-Mar-03
# 25                      0 (0)                       9-Mar-03
# 26                   1 (11)^d                      11-Mar-03
# 27                      0 (0)                       1-Mar-03
# 28                      0 (0)                      24-Feb-03
# 29                    36 (57)                      23-Feb-03
#
#    Date onset last probable case
# 1                       1-Apr-03
# 2                      12-Jun-03
# 3                       3-Jun-03
# 4                      31-May-03
# 5                       5-May-03
# 6                      15-Jun-03
# 7                       3-May-03
# 8                       6-May-03
# 9                       6-May-03
# 10                     17-Apr-03
# 11                     20-Apr-03
# 12                      9-Apr-03
# 13                     22-Apr-03
# 14                      6-May-03
# 15                     20-Apr-03
# 16                      5-May-03
# 17                     27-Feb-03
# 18                     10-May-03
# 19                     19-Mar-03
# 20                      5-May-03
# 21                      5-May-03
# 22                      3-Apr-03
# 23                     26-Mar-03
# 24                     23-Apr-03
# 25                      9-Mar-03
# 26                     27-May-03
# 27                      1-Apr-03
# 28                   13-Jul-03^e
# 29                     14-Apr-03

# %%
# save raw data
df.to_csv('summary_data_raw.csv', index = False)

# %% [markdown]
# # Data Cleaning

# %%
# replace strings / characters
# ===========================

for col in df.columns:
    # replace special notes
    df[col] = df[col].str.replace('\^[abcde]', '')
    # replace with abbreviation
    df[col] = df[col].str.replace('China, ', '')
    df[col] = df[col].str.replace('Special Administrative Region', 'SAR, China')
    
# df

# %%
# extract just the numbers from the columns
# =========================================

cols = ['Cumulative male cases', 'Cumulative female cases', 'Cumulative total cases', 
        'No. of deaths', 'Case fatalities ratio (%)']

for col in cols:
    df[col] = df[col].str.extract('(\d*)')
    
# df

# %%
# extract number, range, percentage ...
df['Median age'] = df['Median age (range)'].str.extract('(\d*)')
df['Age range'] = df['Median age (range)'].str.extract('\((\d+\-\d+)\)')

df['Number of Imported cases'] =  df['Number of imported cases (%)'].str.extract('(\d*)')
df['Percentage of Imported cases'] = df['Number of imported cases (%)'].str.extract('\((\d+)\)')

df['Number of HCW affected'] =  df['Number of HCW affected (%)'].str.extract('(\d*)')
df['Percentage of HCW affected'] = df['Number of HCW affected (%)'].str.extract('\((\d+)\)')

# drop redundant columns
df = df.drop(['Median age (range)', 'Number of imported cases (%)', 'Number of HCW affected (%)'], axis=1)

# %%
# fix date time format
df['Date onset first probable case'] = pd.to_datetime(df['Date onset first probable case'])
df['Date onset last probable case'] = pd.to_datetime(df['Date onset last probable case'])

# %%
# fix empty string with nan
df = df.replace('', np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 1 to 29
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country/Region                  29 non-null     object
#  1   Cumulative male cases           29 non-null     object
#  2   Cumulative female cases         29 non-null     object
#  3   Cumulative total cases          29 non-null     object
#  4   No. of deaths                   29 non-null     object
#  5   Case fatalities ratio (%)       29 non-null     object
#  6   Date onset first probable case  29 non-null     datetime64[ns]
#  7   Date onset last probable case   29 non-null     datetime64[ns]
#  8   Median age                      28 non-null     object
#  9   Age range                       18 non-null     object
#  10  Number of Imported cases        26 non-null     object
#  11  Percentage of Imported cases    26 non-null     object
#  12  Number of HCW affected          29 non-null     object
#  13  Percentage of HCW affected      29 non-null     object
# dtypes: datetime64[ns](2), object(12)
# memory usage: 3.3+ KB

# %%
df
# Out:
#           Country/Region Cumulative male cases Cumulative female cases  \
# 1              Australia                     4                       2
# 2                 Canada                   151                     100
# 3                  China                  2674                    2607
# 4   Hong Kong SAR, China                   977                     778
# 5       Macao SAR, China                     0                       1
# 6                 Taiwan                   218                     128
# 7                 France                     1                       6
# 8                Germany                     4                       5
# 9                  India                     0                       3
# 10             Indonesia                     0                       2
# 11                 Italy                     1                       3
# 12                Kuwait                     1                       0
# 13              Malaysia                     1                       4
# 14              Mongolia                     8                       1
# 15           New Zealand                     1                       0
# 16           Philippines                     8                       6
# 17   Republic of Ireland                     0                       1
# 18     Republic of Korea                     0                       3
# 19               Romania                     0                       1
# 20    Russian Federation                     0                       1
# 21             Singapore                   161                      77
# 22          South Africa                     0                       1
# 23                 Spain                     0                       1
# 24                Sweden                     3                       2
# 25           Switzerland                     0                       1
# 26              Thailand                     5                       4
# 27        United Kingdom                     2                       2
# 28         United States                    13                      14
# 29              Viet Nam                    39                      24
#
#    Cumulative total cases No. of deaths Case fatalities ratio (%)  \
# 1                       6             0                         0
# 2                     251            43                        17
# 3                    5327           349                         7
# 4                    1755           299                        17
# 5                       1             0                         0
# 6                     346            37                        11
# 7                       7             1                        14
# 8                       9             0                         0
# 9                       3             0                         0
# 10                      2             0                         0
# 11                      4             0                         0
# 12                      1             0                         0
# 13                      5             2                        40
# 14                      9             0                         0
# 15                      1             0                         0
# 16                     14             2                        14
# 17                      1             0                         0
# 18                      3             0                         0
# 19                      1             0                         0
# 20                      1             0                         0
# 21                    238            33                        14
# 22                      1             1                       100
# 23                      1             0                         0
# 24                      5             0                         0
# 25                      1             0                         0
# 26                      9             2                        22
# 27                      4             0                         0
# 28                     27             0                         0
# 29                     63             5                         8
#
#    Date onset first probable case Date onset last probable case Median age  \
# 1                      2003-02-26                    2003-04-01         15
# 2                      2003-02-23                    2003-06-12         49
# 3                      2002-11-16                    2003-06-03        NaN
# 4                      2003-02-15                    2003-05-31         40
# 5                      2003-05-05                    2003-05-05         28
# 6                      2003-02-25                    2003-06-15         42
# 7                      2003-03-21                    2003-05-03         49
# 8                      2003-03-09                    2003-05-06         44
# 9                      2003-04-25                    2003-05-06         25
# 10                     2003-04-06                    2003-04-17         56
# 11                     2003-03-12                    2003-04-20         30
# 12                     2003-04-09                    2003-04-09         50
# 13                     2003-03-14                    2003-04-22         30
# 14                     2003-03-31                    2003-05-06         32
# 15                     2003-04-20                    2003-04-20         67
# 16                     2003-02-25                    2003-05-05         41
# 17                     2003-02-27                    2003-02-27         56
# 18                     2003-04-25                    2003-05-10         40
# 19                     2003-03-19                    2003-03-19         52
# 20                     2003-05-05                    2003-05-05         25
# 21                     2003-02-25                    2003-05-05         35
# 22                     2003-04-03                    2003-04-03         62
# 23                     2003-03-26                    2003-03-26         33
# 24                     2003-03-28                    2003-04-23         43
# 25                     2003-03-09                    2003-03-09         35
# 26                     2003-03-11                    2003-05-27         42
# 27                     2003-03-01                    2003-04-01         59
# 28                     2003-02-24                    2003-07-13         36
# 29                     2003-02-23                    2003-04-14         43
#
#    Age range Number of Imported cases Percentage of Imported cases  \
# 1       1-45                        6                          100
# 2       1-98                        5                            2
# 3        NaN                      NaN                          NaN
# 4      0-100                      NaN                          NaN
# 5        NaN                        1                          100
# 6       0-93                       21                            6
# 7        NaN                        7                          100
# 8       4-73                        9                          100
# 9      25-30                        3                          100
# 10     47-65                        2                          100
# 11     25-54                        4                          100
# 12       NaN                        1                          100
# 13     26-84                        5                          100
# 14     17-63                        8                           89
# 15       NaN                        1                          100
# 16     29-73                        7                           50
# 17       NaN                        1                          100
# 18     20-80                        3                          100
# 19       NaN                        1                          100
# 20       NaN                      NaN                          NaN
# 21      1-90                        8                            3
# 22       NaN                        1                          100
# 23       NaN                        1                          100
# 24     33-55                        5                          100
# 25       NaN                        1                          100
# 26      2-79                        9                          100
# 27     28-74                        4                          100
# 28      0-83                       27                          100
# 29     20-76                        1                            2
#
#    Number of HCW affected Percentage of HCW affected
# 1                       0                          0
# 2                     109                         43
# 3                    1002                         19
# 4                     386                         22
# 5                       0                          0
# 6                      68                         20
# 7                       2                         29
# 8                       1                         11
# 9                       0                          0
# 10                      0                          0
# 11                      0                          0
# 12                      0                          0
# 13                      0                          0
# 14                      0                          0
# 15                      0                          0
# 16                      4                         29
# 17                      0                          0
# 18                      0                          0
# 19                      0                          0
# 20                      0                          0
# 21                     97                         41
# 22                      0                          0
# 23                      0                          0
# 24                      0                          0
# 25                      0                          0
# 26                      1                         11
# 27                      0                          0
# 28                      0                          0
# 29                     36                         57

# %%
# save clean data
df.to_csv('summary_data_clean.csv', index = False)
